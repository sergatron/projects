# %%
import pandas as pd
import numpy as np
import requests
import json
import os
import time
# import random

# %%
# os.chdir('/')
print(os.getcwd())
# Out:
# C:\Users\smouz\Google Drive\jupyter_notebook\capstone

# %%
os.environ['HOMEPATH']
# Out:
# '\\Users\\smouz'

# %%
if 'Capstone' not in os.getcwd():
    os.chdir(str(os.environ['HOMEPATH']) + '\OneDrive\Desktop\DataSci\DataSci_Python\SP-Capstone-PY\Capstone')
print('Working directory:', os.getcwd())
# Out:
# Working directory: C:\Users\smouz\OneDrive\Desktop\DataSci\DataSci_Python\SP-Capstone-PY\Capstone

# %% [markdown]
# ### Dataset
# Import data and count missing values for solar radiation. These values will be filled using data obtained through an API.

# %%
pv_df = pd.read_csv('pv_df_short.csv', low_memory=False)
pv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886655 entries, 0 to 886654
# Data columns (total 23 columns):
# state                          886655 non-null object
# date_installed                 886655 non-null object
# incentive_prog_names           710174 non-null object
# size_kw                        886655 non-null float64
# zipcode                        886655 non-null int64
# install_type                   886655 non-null object
# installer                      641410 non-null object
# cost_per_watt                  661381 non-null float64
# cost                           661288 non-null float64
# city                           712730 non-null object
# utility_clean                  706910 non-null object
# tech_1                         533924 non-null object
# model1_clean                   533924 non-null object
# county                         877357 non-null object
# annual_pv_prod                 886655 non-null float64
# annual_insolation              695447 non-null float64
# rebate                         332054 non-null float64
# sales_tax_cost                 300305 non-null float64
# tilt1                          361678 non-null float64
# tracking_type                  495488 non-null object
# azimuth1                       341025 non-null float64
# reported_annual_energy_prod    184936 non-null float64
# 3rdparty                       886655 non-null int64
# dtypes: float64(10), int64(2), object(11)
# memory usage: 155.6+ MB

# %%
def missing_val_count(df, col_name, show_missing=False):
    '''
    Count missing values and show its index.
    Returns DF if show_missing=True
    '''
    if show_missing == True:
        return df[df.loc[:, col_name].isnull()]
    else:
        return col_name, np.count_nonzero(df.loc[:, col_name].isnull().values)

# %%
# format zipcode
pv_df['zipcode'] = pv_df['zipcode'].map('{:05d}'.format)

# %%
missing_val_count(pv_df, 'annual_insolation')
# Out:
# ('annual_insolation', 191208)

# %% [markdown]
# ### NREL API
# Obtain solar radiation data using API
#
# Only 1,000 requests can be made per hour. At first glance, with 191,208 missing values it would take about 191 hours to get all values through the API. In terms of days, it would take roughly 8 days to complete.

# %%
pv_df.groupby('state')['annual_insolation'].mean().sort_values()
# Out:
# state
# ct    4.209904
# ma    4.232425
# oh    4.298287
# nj    4.331036
# ny    4.351757
# pa    4.380561
# or    4.404228
# wi    4.415797
# mn    4.459524
# nh    4.473857
# ri    4.539976
# md    4.593002
# de    4.613283
# dc    4.618089
# mo    4.808802
# ar    5.050008
# ut    5.071128
# fl    5.219673
# tx    5.307899
# ca    5.468537
# nv    6.160320
# nm    6.383599
# az    6.464277
# ak         NaN
# al         NaN
# co         NaN
# ga         NaN
# hi         NaN
# ia         NaN
# id         NaN
# il         NaN
# in         NaN
# ks         NaN
# ky         NaN
# la         NaN
# me         NaN
# mi         NaN
# ms         NaN
# mt         NaN
# nc         NaN
# nd         NaN
# ne         NaN
# ok         NaN
# pr         NaN
# sc         NaN
# sd         NaN
# tn         NaN
# va         NaN
# vt         NaN
# wa         NaN
# wv         NaN
# wy         NaN
# Name: annual_insolation, dtype: float64

# %%
pv_df[pv_df['state'] == 'ca'].annual_insolation.describe()
# Out:
# count    431109.000000
# mean          5.468537
# std           0.383630
# min           1.268869
# 25%           5.354301
# 50%           5.487600
# 75%           5.644894
# max           6.761269
# Name: annual_insolation, dtype: float64

# %%
pv_df['city_state'] = pv_df['city'] + ', ' + pv_df['state']

# %%
pv_df['city_state'].nunique()
# Out:
# 9584

# %%
print(pv_df['zipcode'].nunique())
print(pv_df['county'].nunique())
# Out:
# 11340
# 846

# %%
def get_data(baseurl, params=None):
    """ Returns results of a request in JSON format"""
    re = requests.get(baseurl, params)
    try:
        if re.status_code == 200:
            return re.json()
        else:
            return re.json()
    except Exception as e:
        print(e)

# %%
pv_df[['county', 'state']].tail(20)
# Out:
#        county state
# 886635    NaN    ny
# 886636    NaN    ny
# 886637    NaN    ny
# 886638    NaN    oh
# 886639    NaN    oh
# 886640    NaN    oh
# 886641    NaN    oh
# 886642    NaN    va
# 886643    NaN    pa
# 886644    NaN    pa
# 886645    NaN    pa
# 886646    NaN    pa
# 886647    NaN    pa
# 886648    NaN    pa
# 886649    NaN    pa
# 886650    NaN    md
# 886651    NaN    md
# 886652    NaN    md
# 886653    NaN    md
# 886654    NaN    md

# %% [markdown]
# ### Insolation for each county
# For each unique county, we'll obtain the annual insolation value. The only parameter that's really needed in this case is the county so we'll keep all other parameters constant and interate through counties. Also, it is a good idea to implement a time delay between each request to be respectful of the servers.

# %%
# create subset DF where annual_insolation values are missing
pv_subset = pv_df[pv_df['annual_insolation'].isnull()]
print(pv_subset.city_state.nunique())
# Out:
# 1826

# %%
# combine count and state to create an address for a request
counties_addr = pv_subset['county'] + ', ' + pv_subset['state']
print(counties_addr.nunique())

# create numpy array of unique addreses
counties = counties_addr.unique()
np.count_nonzero(counties_addr.notnull().values)
# Out:
# 1069
# array(['travis, tx', nan, 'seminole, fl', ..., 'eddy, nm', 'union, nm',
#        'modoc, ca'], dtype=object)

# %%
# pd.Series(counties).isnull()
# type(counties[1]) == float

# %%
# iterate over counties and extract annual insolation
annual_insol = []
address_input = []
API_KEY = 'my_key'
url = 'https://developer.nrel.gov/api/pvwatts/v6.json?'
for address in counties:
    # np.nan is a float, therefore do no use
    if type(address) == str:
        try:
#             print('\nWorking...')
#             print('Requesting address:', address)
            params_in = {'address': address,
                         'system_capacity': 5,
                         'azimuth': 180,
                         'tilt': 40,
                         'tracking': 1,
                         'api_key': API_KEY,
                         'array_type': 1,
                         'module_type': 0,
                         'losses': 10
                         }
            # make request
            res = get_data(url, params=params_in)
            annual_insol.append(res['outputs']['solrad_annual'])
            address_input.append(res['inputs']['address'])
            time.sleep(random.randint(2,6))
        except Exception as e:
            print(e)
# Out:
# Working...
# Requesting address: travis, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: seminole, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: pinal, az
# Sleeping 6 seconds
#
# Working...
# Requesting address: pima, az
# Sleeping 6 seconds
#
# Working...
# Requesting address: orange, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: dc, dc
# Sleeping 6 seconds
#
# Working...
# Requesting address: sullivan, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: tompkins, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: queens, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: oneida, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: columbia, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: montgomery, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: warren, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: nassau, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: suffolk, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: boone, mo
# Sleeping 6 seconds
#
# Working...
# Requesting address: onondaga, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: oswego, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: kings, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: erie, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: westchester, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: dutchess, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: broome, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: wayne, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: saratoga, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: orange, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: ontario, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: new york, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: bronx, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: ulster, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: monroe, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: richmond, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: bernalillo, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: new castle, de
# Sleeping 6 seconds
#
# Working...
# Requesting address: kent, de
# Sleeping 6 seconds
#
# Working...
# Requesting address: dakota, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: dunn, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: washington, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: pierce, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: polk, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: blue earth, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: lamar, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: collin, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: wise, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: dallas, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: tarrant, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: sussex, de
# Sleeping 6 seconds
#
# Working...
# Requesting address: grand traverse, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: antrim, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: forrest, ms
# Sleeping 6 seconds
#
# Working...
# Requesting address: lafayette, ms
# Sleeping 6 seconds
#
# Working...
# Requesting address: oktibbeha, ms
# Sleeping 6 seconds
#
# Working...
# Requesting address: simpson, ms
# Sleeping 6 seconds
#
# Working...
# Requesting address: howard, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: carroll, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: baltimore, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: washington, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: montgomery, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: anne arundel, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: st mary's, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: dorchester, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: calvert, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: caroline, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: prince george's, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: harford, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: frederick, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: charles, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: cecil, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: wicomico, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: kent, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: worcester, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: queen anne's, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: talbot, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: allegany, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: garrett, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: somerset, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: santa clara, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: bexar, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: comal, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: medina, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: kendall, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: williamson, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: atascosa, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: guadalupe, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: denver, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: attala, ms
# Sleeping 6 seconds
#
# Working...
# Requesting address: alameda, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: seneca, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: yates, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: northumberland, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: union, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: blair, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: berks, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: bedford, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: lebanon, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: logan, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: stark, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: marshall, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: spencer, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: jo daviess, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: clark, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: loudoun, va
# Sleeping 6 seconds
#
# Working...
# Requesting address: lowndes, ms
# Sleeping 6 seconds
#
# Working...
# Requesting address: fairfax, va
# Sleeping 6 seconds
#
# Working...
# Requesting address: pulaski, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: reno, ks
# Sleeping 6 seconds
#
# Working...
# Requesting address: sedgwick, ks
# Sleeping 6 seconds
#
# Working...
# Requesting address: strafford, nh
# Sleeping 6 seconds
#
# Working...
# Requesting address: morgan, wv
# Sleeping 6 seconds
#
# Working...
# Requesting address: berkeley, wv
# Sleeping 6 seconds
#
# Working...
# Requesting address: kanawha, wv
# Sleeping 6 seconds
#
# Working...
# Requesting address: nicholas, wv
# Sleeping 6 seconds
#
# Working...
# Requesting address: fayette, wv
# Sleeping 6 seconds
#
# Working...
# Requesting address: jefferson, wv
# Sleeping 6 seconds
#
# Working...
# Requesting address: greenbrier, wv
# Sleeping 6 seconds
#
# Working...
# Requesting address: cumberland, me
# Sleeping 6 seconds
#
# Working...
# Requesting address: jefferson, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: pueblo, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: vanderburgh, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: white, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: warrick, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: posey, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: marion, wv
# Sleeping 6 seconds
#
# Working...
# Requesting address: salt lake, ut
# Sleeping 6 seconds
#
# Working...
# Requesting address: utah, ut
# Sleeping 6 seconds
#
# Working...
# Requesting address: davis, ut
# Sleeping 6 seconds
#
# Working...
# Requesting address: washington, ut
# Sleeping 6 seconds
#
# Working...
# Requesting address: uintah, ut
# Sleeping 6 seconds
#
# Working...
# Requesting address: weber, ut
# Sleeping 6 seconds
#
# Working...
# Requesting address: johnson, ia
# Sleeping 6 seconds
#
# Working...
# Requesting address: linn, ia
# Sleeping 6 seconds
#
# Working...
# Requesting address: whatcom, wa
# Sleeping 6 seconds
#
# Working...
# Requesting address: medina, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: holmes, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: coshocton, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: tuscarawas, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: allegheny, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: hampshire, ma
# Sleeping 6 seconds
#
# Working...
# Requesting address: hampden, ma
# Sleeping 6 seconds
#
# Working...
# Requesting address: chester, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: centre, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: lancaster, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: wexford, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: coconino, az
# Sleeping 6 seconds
#
# Working...
# Requesting address: maricopa, az
# Sleeping 6 seconds
#
# Working...
# Requesting address: gila, az
# Sleeping 6 seconds
#
# Working...
# Requesting address: yuma, az
# Sleeping 6 seconds
#
# Working...
# Requesting address: navajo, az
# Sleeping 6 seconds
#
# Working...
# Requesting address: yavapai, az
# Sleeping 6 seconds
#
# Working...
# Requesting address: la paz, az
# Sleeping 6 seconds
#
# Working...
# Requesting address: monroe, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: denton, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: webb, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: tulare, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: santa barbara, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: san mateo, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: san diego, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: riverside, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: san francisco, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: ventura, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: los angeles, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: napa, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: yolo, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: contra costa, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: sonoma, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: butte, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: lake, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: kings, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: santa cruz, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: marin, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: orange, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: fresno, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: placer, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: san bernardino, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: nevada, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: el dorado, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: san luis obispo, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: tuolumne, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: madera, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: monterey, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: kern, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: humboldt, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: san benito, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: solano, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: merced, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: san joaquin, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: shasta, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: mendocino, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: calaveras, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: plumas, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: glenn, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: sutter, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: tehama, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: amador, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: mono, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: stanislaus, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: imperial, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: alpine, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: yuba, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: sacramento, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: mariposa, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: sierra, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: colusa, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: merrimack, nh
# Sleeping 6 seconds
#
# Working...
# Requesting address: schuyler, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: bucks, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: houghton, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: suffolk, ma
# Sleeping 6 seconds
#
# Working...
# Requesting address: franklin, ma
# Sleeping 6 seconds
#
# Working...
# Requesting address: plymouth, ma
# Sleeping 6 seconds
#
# Working...
# Requesting address: middlesex, ma
# Sleeping 6 seconds
#
# Working...
# Requesting address: norfolk, ma
# Sleeping 6 seconds
#
# Working...
# Requesting address: worcester, ma
# Sleeping 6 seconds
#
# Working...
# Requesting address: essex, ma
# Sleeping 6 seconds
#
# Working...
# Requesting address: barnstable, ma
# Sleeping 6 seconds
#
# Working...
# Requesting address: dukes, ma
# Sleeping 6 seconds
#
# Working...
# Requesting address: berkshire, ma
# Sleeping 6 seconds
#
# Working...
# Requesting address: bristol, ma
# Sleeping 6 seconds
#
# Working...
# Requesting address: washington, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: mahoning, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: knox, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: jefferson, ky
# Sleeping 6 seconds
#
# Working...
# Requesting address: jessamine, ky
# Sleeping 6 seconds
#
# Working...
# Requesting address: johnson, mo
# Sleeping 6 seconds
#
# Working...
# Requesting address: addison, vt
# Sleeping 6 seconds
#
# Working...
# Requesting address: monroe, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: bartholomew, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: porter, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: morris, nj
# Sleeping 6 seconds
#
# Working...
# Requesting address: otero, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: douglas, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: st charles, mo
# Sleeping 6 seconds
#
# Working...
# Requesting address: st louis, mo
# Sleeping 6 seconds
#
# Working...
# Requesting address: jefferson, mo
# Sleeping 6 seconds
#
# Working...
# Requesting address: franklin, mo
# Sleeping 6 seconds
#
# Working...
# Requesting address: washington, mo
# Sleeping 6 seconds
#
# Working...
# Requesting address: lincoln, mo
# Sleeping 6 seconds
#
# Working...
# Requesting address: pike, mo
# Sleeping 6 seconds
#
# Working...
# Requesting address: mesa, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: garfield, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: adams, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: boulder, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: broomfield, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: larimer, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: arapahoe, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: weld, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: park, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: eagle, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: montrose, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: delta, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: warren, mo
# Sleeping 6 seconds
#
# Working...
# Requesting address: summit, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: dane, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: sauk, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: taylor, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: oconto, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: brown, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: manitowoc, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: price, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: winnebago, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: eau claire, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: milwaukee, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: wood, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: iowa, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: door, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: vernon, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: columbia, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: lafayette, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: sheboygan, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: chippewa, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: portage, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: jefferson, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: ozaukee, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: racine, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: waushara, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: la crosse, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: green, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: jackson, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: waukesha, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: green lake, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: walworth, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: marinette, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: kenosha, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: douglas, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: kewaunee, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: waupaca, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: outagamie, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: santa cruz, az
# Sleeping 6 seconds
#
# Working...
# Requesting address: windham, vt
# Sleeping 6 seconds
#
# Working...
# Requesting address: rutland, vt
# Sleeping 6 seconds
#
# Working...
# Requesting address: washington, vt
# Sleeping 6 seconds
#
# Working...
# Requesting address: chittenden, vt
# Sleeping 6 seconds
#
# Working...
# Requesting address: windsor, vt
# Sleeping 6 seconds
#
# Working...
# Requesting address: lamoille, vt
# Sleeping 6 seconds
#
# Working...
# Requesting address: osceola, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: cochise, az
# Sleeping 6 seconds
#
# Working...
# Requesting address: florence, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: oneida, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: vilas, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: cook, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: litchfield, ct
# Sleeping 6 seconds
#
# Working...
# Requesting address: fairfield, ct
# Sleeping 6 seconds
#
# Working...
# Requesting address: walton, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: okaloosa, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: levy, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: lee, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: charlotte, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: manatee, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: sarasota, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: mohave, az
# Sleeping 6 seconds
#
# Working...
# Requesting address: clark, nv
# Sleeping 6 seconds
#
# Working...
# Requesting address: washoe, nv
# Sleeping 6 seconds
#
# Working...
# Requesting address: lassen, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: montgomery, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: york, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: clinton, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: snyder, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: lehigh, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: wake, nc
# Sleeping 6 seconds
#
# Working...
# Requesting address: fulton, ga
# Sleeping 6 seconds
#
# Working...
# Requesting address: wayne, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: rowan, nc
# Sleeping 6 seconds
#
# Working...
# Requesting address: chemung, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: chautauqua, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: ingham, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: beaver, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: kent, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: van buren, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: ottawa, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: kalamazoo, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: berrien, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: clinton, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: ionia, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: monroe, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: newaygo, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: barry, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: charlevoix, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: allegan, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: oakland, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: mecosta, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: leelanau, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: east baton rouge, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: lapeer, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: muskegon, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: orange, nc
# Sleeping 6 seconds
#
# Working...
# Requesting address: washtenaw, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: dickinson, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: alger, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: iberia, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: jefferson, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: orleans, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: st tammany, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: lafayette, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: tangipahoa, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: avoyelles, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: kauai, hi
# Sleeping 6 seconds
#
# Working...
# Requesting address: honolulu, hi
# Sleeping 6 seconds
#
# Working...
# Requesting address: bennington, vt
# Sleeping 6 seconds
#
# Working...
# Requesting address: vermilion, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: ascension, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: macomb, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: st clair, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: morgan, mo
# Sleeping 6 seconds
#
# Working...
# Requesting address: marathon, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: cook, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: lake, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: peoria, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: dupage, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: rock island, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: sangamon, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: kane, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: mchenry, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: vermilion, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: cheyenne, ne
# Sleeping 6 seconds
#
# Working...
# Requesting address: grafton, nh
# Sleeping 6 seconds
#
# Working...
# Requesting address: coos, nh
# Sleeping 6 seconds
#
# Working...
# Requesting address: rockingham, nh
# Sleeping 6 seconds
#
# Working...
# Requesting address: hillsborough, nh
# Sleeping 6 seconds
#
# Working...
# Requesting address: belknap, nh
# Sleeping 6 seconds
#
# Working...
# Requesting address: carroll, nh
# Sleeping 6 seconds
#
# Working...
# Requesting address: cheshire, nh
# Sleeping 6 seconds
#
# Working...
# Requesting address: sullivan, nh
# Sleeping 6 seconds
#
# Working...
# Requesting address: richland, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: crawford, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: adams, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: calumet, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: clark, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: douglas, nv
# Sleeping 6 seconds
#
# Working...
# Requesting address: storey, nv
# Sleeping 6 seconds
#
# Working...
# Requesting address: humboldt, nv
# Sleeping 6 seconds
#
# Working...
# Requesting address: davidson, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: montgomery, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: jeff davis, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: brewster, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: el paso, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: tom green, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: presidio, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: nolan, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: hidalgo, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: bowie, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: waller, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: maverick, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: cameron, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: bell, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: bee, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: archer, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: hardin, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: leon, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: franklin, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: galveston, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: orange, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: nueces, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: grimes, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: jim wells, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: taylor, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: madison, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: inyo, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: stevens, wa
# Sleeping 6 seconds
#
# Working...
# Requesting address: yukon-koyukuk, ak
# 'solrad_annual'
#
# Working...
# Requesting address: hood river, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: la salle, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: st clair, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: stephenson, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: mcdonough, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: grundy, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: carroll, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: massac, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: iroquois, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: dekalb, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: champaign, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: boone, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: winnebago, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: kennebec, me
# Sleeping 6 seconds
#
# Working...
# Requesting address: baltimore city, md
# Sleeping 6 seconds
#
# Working...
# Requesting address: goodhue, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: ramsey, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: hennepin, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: carlton, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: jackson, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: cheatham, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: bledsoe, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: cumberland, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: williamson, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: marion, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: rutherford, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: putnam, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: hardin, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: franklin, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: smith, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: knox, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: hamilton, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: fayette, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: coffee, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: hickman, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: greene, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: sumner, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: dekalb, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: shelby, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: johnson, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: macon, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: robertson, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: wilson, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: marshall, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: maury, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: hamblen, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: carter, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: washington, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: montgomery, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: bedford, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: brevard, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: putnam, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: marion, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: pinellas, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: palm beach, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: leon, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: volusia, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: alachua, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: pasco, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: hillsborough, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: martin, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: taylor, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: monroe, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: miami-dade, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: collier, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: duval, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: lake, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: columbia, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: nassau, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: st johns, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: hernando, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: flagler, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: johnson, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: gadsden, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: indian river, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: st lucie, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: clay, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: niagara, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: franklin, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: broward, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: okeechobee, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: citrus, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: hendry, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: polk, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: gulf, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: jefferson, al
# Sleeping 6 seconds
#
# Working...
# Requesting address: jackson, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: santa rosa, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: glades, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: highlands, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: sumter, fl
# Sleeping 6 seconds
#
# Working...
# Requesting address: fulton, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: laurens, ga
# Sleeping 6 seconds
#
# Working...
# Requesting address: livingston, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: genesee, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: newport, ri
# Sleeping 6 seconds
#
# Working...
# Requesting address: umatilla, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: franklin, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: essex, nj
# Sleeping 6 seconds
#
# Working...
# Requesting address: hunterdon, nj
# Sleeping 6 seconds
#
# Working...
# Requesting address: somerset, nj
# Sleeping 6 seconds
#
# Working...
# Requesting address: tolland, ct
# Sleeping 6 seconds
#
# Working...
# Requesting address: monmouth, nj
# Sleeping 6 seconds
#
# Working...
# Requesting address: mercer, nj
# Sleeping 6 seconds
#
# Working...
# Requesting address: passaic, nj
# Sleeping 6 seconds
#
# Working...
# Requesting address: minnehaha, sd
# Sleeping 6 seconds
#
# Working...
# Requesting address: southeast fairbanks, ak
# 'solrad_annual'
#
# Working...
# Requesting address: ada, id
# Sleeping 6 seconds
#
# Working...
# Requesting address: hancock, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: york, me
# Sleeping 6 seconds
#
# Working...
# Requesting address: oklahoma, ok
# Sleeping 6 seconds
#
# Working...
# Requesting address: cleveland, ok
# Sleeping 6 seconds
#
# Working...
# Requesting address: sagadahoc, me
# Sleeping 6 seconds
#
# Working...
# Requesting address: multnomah, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: jackson, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: lancaster, ne
# Sleeping 6 seconds
#
# Working...
# Requesting address: bradford, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: waldo, me
# Sleeping 6 seconds
#
# Working...
# Requesting address: morgan, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: steuben, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: howard, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: elkhart, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: kosciusko, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: marion, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: floyd, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: stone, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: rockingham, va
# Sleeping 6 seconds
#
# Working...
# Requesting address: vigo, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: wabash, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: macoupin, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: clinton, mo
# Sleeping 6 seconds
#
# Working...
# Requesting address: providence, ri
# Sleeping 6 seconds
#
# Working...
# Requesting address: hawaii, hi
# Sleeping 6 seconds
#
# Working...
# Requesting address: union, ms
# Sleeping 6 seconds
#
# Working...
# Requesting address: lauderdale, ms
# Sleeping 6 seconds
#
# Working...
# Requesting address: newton, ms
# Sleeping 6 seconds
#
# Working...
# Requesting address: mason, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: jackson, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: summit, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: penobscot, me
# Sleeping 6 seconds
#
# Working...
# Requesting address: klamath, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: mineral, wv
# Sleeping 6 seconds
#
# Working...
# Requesting address: kalkaska, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: deschutes, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: king, wa
# Sleeping 6 seconds
#
# Working...
# Requesting address: madison, ms
# Sleeping 6 seconds
#
# Working...
# Requesting address: rock, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: st louis city, mo
# Sleeping 6 seconds
#
# Working...
# Requesting address: monroe, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: adams, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: st charles, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: boone, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: pierce, wa
# Sleeping 6 seconds
#
# Working...
# Requesting address: okanogan, wa
# Sleeping 6 seconds
#
# Working...
# Requesting address: oxford, me
# Sleeping 6 seconds
#
# Working...
# Requesting address: new hanover, nc
# Sleeping 6 seconds
#
# Working...
# Requesting address: yamhill, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: delaware, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: portage, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: lorain, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: cuyahoga, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: wayne, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: jefferson, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: washington, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: chippewa, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: el paso, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: albany, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: lincoln, nc
# Sleeping 6 seconds
#
# Working...
# Requesting address: clinton, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: montgomery, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: dubuque, ia
# Sleeping 6 seconds
#
# Working...
# Requesting address: champaign, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: buffalo, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: fillmore, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: winona, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: scott, ms
# Sleeping 6 seconds
#
# Working...
# Requesting address: thurston, wa
# Sleeping 6 seconds
#
# Working...
# Requesting address: oceana, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: washington, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: harrison, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: dearborn, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: ripley, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: st joseph, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: noble, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: pike, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: lake, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: orange, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: cass, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: jefferson, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: laporte, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: wayne, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: scott, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: franklin, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: clark, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: benton, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: wadena, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: hubbard, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: kandiyohi, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: essex, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: schenectady, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: cayuga, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: chenango, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: madison, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: greene, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: cortland, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: lewis, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: allegany, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: franklin, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: livingston, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: herkimer, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: st lawrence, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: orleans, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: steuben, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: wyoming, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: rensselaer, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: tioga, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: schoharie, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: genesee, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: otsego, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: putnam, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: cattaraugus, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: washington, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: fulton, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: delaware, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: rockland, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: hamilton, ny
# Sleeping 6 seconds
#
# Working...
# Requesting address: smith, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: rockwall, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: ellis, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: mclennan, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: cherokee, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: navarro, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: robertson, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: hamilton, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: san jacinto, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: clay, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: rusk, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: brown, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: morris, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: parker, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: hudspeth, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: van zandt, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: grayson, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: aransas, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: colorado, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: harrison, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: tyler, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: real, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: johnson, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: young, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: pawnee, ks
# Sleeping 6 seconds
#
# Working...
# Requesting address: butler, de
# Sleeping 6 seconds
#
# Working...
# Requesting address: clear creek, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: camden, nj
# Sleeping 6 seconds
#
# Working...
# Requesting address: burlington, nj
# Sleeping 6 seconds
#
# Working...
# Requesting address: gloucester, nj
# Sleeping 6 seconds
#
# Working...
# Requesting address: middlesex, nj
# Sleeping 6 seconds
#
# Working...
# Requesting address: salem, nj
# Sleeping 6 seconds
#
# Working...
# Requesting address: washington, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: clackamas, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: marion, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: polk, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: clatsop, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: benton, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: linn, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: lane, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: delaware, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: philadelphia, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: koochiching, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: st louis, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: susquehanna, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: shiawassee, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: cumberland, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: perry, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: schuylkill, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: lincoln, me
# Sleeping 6 seconds
#
# Working...
# Requesting address: dubois, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: dauphin, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: adams, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: riley, ks
# Sleeping 6 seconds
#
# Working...
# Requesting address: douglas, ks
# Sleeping 6 seconds
#
# Working...
# Requesting address: matanuska-susitna, ak
# 'solrad_annual'
#
# Working...
# Requesting address: new london, ct
# Sleeping 6 seconds
#
# Working...
# Requesting address: houston, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: fairfield, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: mathews, va
# Sleeping 6 seconds
#
# Working...
# Requesting address: allamakee, ia
# Sleeping 6 seconds
#
# Working...
# Requesting address: winneshiek, ia
# Sleeping 6 seconds
#
# Working...
# Requesting address: phelps, mo
# Sleeping 6 seconds
#
# Working...
# Requesting address: island, wa
# Sleeping 6 seconds
#
# Working...
# Requesting address: ravalli, mt
# Sleeping 6 seconds
#
# Working...
# Requesting address: hancock, me
# Sleeping 6 seconds
#
# Working...
# Requesting address: monongalia, wv
# Sleeping 6 seconds
#
# Working...
# Requesting address: summers, wv
# Sleeping 6 seconds
#
# Working...
# Requesting address: st bernard, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: ouachita, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: walla walla, wa
# Sleeping 6 seconds
#
# Working...
# Requesting address: klickitat, wa
# Sleeping 6 seconds
#
# Working...
# Requesting address: franklin, wa
# Sleeping 6 seconds
#
# Working...
# Requesting address: ferry, wa
# Sleeping 6 seconds
#
# Working...
# Requesting address: wasco, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: benton, wa
# Sleeping 6 seconds
#
# Working...
# Requesting address: sherman, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: wallowa, or
# Sleeping 6 seconds
#
# Working...
# Requesting address: jefferson, wa
# Sleeping 6 seconds
#
# Working...
# Requesting address: fairbanks north star, ak
# 'solrad_annual'
#
# Working...
# Requesting address: lane, ks
# Sleeping 6 seconds
#
# Working...
# Requesting address: hays, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: cass, nd
# Sleeping 6 seconds
#
# Working...
# Requesting address: overton, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: lewis, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: cannon, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: blount, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: perry, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: grainger, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: greene, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: macon, il
# Sleeping 6 seconds
#
# Working...
# Requesting address: allen, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: allen, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: lagrange, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: defiance, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: tippecanoe, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: st joseph, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: fulton, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: cass, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: miami, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: geauga, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: hampshire, wv
# Sleeping 6 seconds
#
# Working...
# Requesting address: fayette, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: spokane, wa
# Sleeping 6 seconds
#
# Working...
# Requesting address: erie, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: clarion, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: crawford, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: wayne, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: juniata, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: warren, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: greenlee, az
# Sleeping 6 seconds
#
# Working...
# Requesting address: cole, mo
# Sleeping 6 seconds
#
# Working...
# Requesting address: callaway, mo
# Sleeping 6 seconds
#
# Working...
# Requesting address: camden, mo
# Sleeping 6 seconds
#
# Working...
# ...
# Sleeping 6 seconds
#
# Working...
# Requesting address: durham, nc
# Sleeping 6 seconds
#
# Working...
# Requesting address: pickens, sc
# Sleeping 6 seconds
#
# Working...
# Requesting address: rapides, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: horry, sc
# Sleeping 6 seconds
#
# Working...
# Requesting address: washington, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: butler, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: lucas, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: yancey, nc
# Sleeping 6 seconds
#
# Working...
# Requesting address: saluda, sc
# Sleeping 6 seconds
#
# Working...
# Requesting address: jackson, al
# Sleeping 6 seconds
#
# Working...
# Requesting address: henderson, nc
# Sleeping 6 seconds
#
# Working...
# Requesting address: abbeville, sc
# Sleeping 6 seconds
#
# Working...
# Requesting address: lincoln, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: hanover, va
# Sleeping 6 seconds
#
# Working...
# Requesting address: yellowstone, mt
# Sleeping 6 seconds
#
# Working...
# Requesting address: sandoval, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: hudson, nj
# Sleeping 6 seconds
#
# Working...
# Requesting address: gibson, in
# Sleeping 6 seconds
#
# Working...
# Requesting address: chowan, nc
# Sleeping 6 seconds
#
# Working...
# Requesting address: lincoln, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: newton, ar
# 'solrad_annual'
#
# Working...
# Requesting address: benton, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: polk, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: lee, ms
# Sleeping 6 seconds
#
# Working...
# Requesting address: anoka, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: lake, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: olmsted, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: rice, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: wright, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: crow wing, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: isanti, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: itasca, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: polk, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: sherburne, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: pine, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: brown, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: beltrami, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: chisago, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: le sueur, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: stearns, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: todd, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: redwood, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: wabasha, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: kanabec, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: mille lacs, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: morrison, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: scott, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: grant, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: otter tail, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: pope, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: cottonwood, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: garland, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: johnson, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: crawford, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: carroll, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: madison, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: white, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: saline, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: marion, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: sebastian, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: van buren, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: pope, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: bradley, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: boone, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: baxter, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: fulton, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: grant, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: warren, ms
# Sleeping 6 seconds
#
# Working...
# Requesting address: dekalb, ga
# Sleeping 6 seconds
#
# Working...
# Requesting address: roscommon, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: grand, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: brunswick, nc
# Sleeping 6 seconds
#
# Working...
# Requesting address: shenandoah, va
# Sleeping 6 seconds
#
# Working...
# Requesting address: frederick, va
# Sleeping 6 seconds
#
# Working...
# Requesting address: forsyth, ga
# Sleeping 6 seconds
#
# Working...
# Requesting address: cache, ut
# Sleeping 6 seconds
#
# Working...
# Requesting address: faulkner, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: northampton, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: lycoming, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: mifflin, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: columbia, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: washington, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: montour, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: carbon, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: wyoming, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: butler, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: westmoreland, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: lackawanna, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: armstrong, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: cambria, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: huntingdon, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: jefferson, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: albemarle, va
# Sleeping 6 seconds
#
# Working...
# Requesting address: scott, ar
# Sleeping 6 seconds
#
# Working...
# Requesting address: madison, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: haywood, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: clarke, va
# Sleeping 6 seconds
#
# Working...
# Requesting address: los alamos, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: santa fe, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: clay, wv
# Sleeping 6 seconds
#
# Working...
# Requesting address: cumberland, nj
# Sleeping 6 seconds
#
# Working...
# Requesting address: york, sc
# Sleeping 6 seconds
#
# Working...
# Requesting address: burke, ga
# Sleeping 6 seconds
#
# Working...
# Requesting address: haywood, nc
# Sleeping 6 seconds
#
# Working...
# Requesting address: prince george, va
# Sleeping 6 seconds
#
# Working...
# Requesting address: lauderdale, al
# Sleeping 6 seconds
#
# Working...
# Requesting address: russell, al
# Sleeping 6 seconds
#
# Working...
# Requesting address: livingston, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: hot springs, wy
# Sleeping 6 seconds
#
# Working...
# Requesting address: licking, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: oconee, sc
# Sleeping 6 seconds
#
# Working...
# Requesting address: richmond, va
# Sleeping 6 seconds
#
# Working...
# Requesting address: idaho, id
# Sleeping 6 seconds
#
# Working...
# Requesting address: west baton rouge, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: monroe, wv
# Sleeping 6 seconds
#
# Working...
# Requesting address: platte, wy
# Sleeping 6 seconds
#
# Working...
# Requesting address: beaufort, nc
# Sleeping 6 seconds
#
# Working...
# Requesting address: san miguel, co
# Sleeping 6 seconds
#
# Working...
# Requesting address: beaufort, sc
# Sleeping 6 seconds
#
# Working...
# Requesting address: chesterfield, sc
# Sleeping 6 seconds
#
# Working...
# Requesting address: butler, al
# Sleeping 6 seconds
#
# Working...
# Requesting address: harris, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: sheridan, wy
# Sleeping 6 seconds
#
# Working...
# Requesting address: st landry, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: natrona, wy
# Sleeping 6 seconds
#
# Working...
# Requesting address: unicoi, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: roane, wv
# Sleeping 6 seconds
#
# Working...
# Requesting address: comanche, ok
# Sleeping 6 seconds
#
# Working...
# Requesting address: dona ana, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: alleghany, va
# Sleeping 6 seconds
#
# Working...
# Requesting address: transylvania, nc
# Sleeping 6 seconds
#
# Working...
# Requesting address: jefferson, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: morgan, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: maui, hi
# Sleeping 6 seconds
#
# Working...
# Requesting address: iberville, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: chatham, ga
# Sleeping 6 seconds
#
# Working...
# Requesting address: albany, wy
# Sleeping 6 seconds
#
# Working...
# Requesting address: trumbull, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: webster, ms
# Sleeping 6 seconds
#
# Working...
# Requesting address: wood, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: park, mt
# Sleeping 6 seconds
#
# Working...
# Requesting address: clermont, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: hart, ky
# Sleeping 6 seconds
#
# Working...
# Requesting address: esmeralda, nv
# Sleeping 6 seconds
#
# Working...
# Requesting address: morgan, al
# Sleeping 6 seconds
#
# Working...
# Requesting address: chambers, al
# Sleeping 6 seconds
#
# Working...
# Requesting address: highland, va
# Sleeping 6 seconds
#
# Working...
# Requesting address: cullman, al
# Sleeping 6 seconds
#
# Working...
# Requesting address: nacogdoches, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: arlington, va
# Sleeping 6 seconds
#
# Working...
# Requesting address: colbert, al
# Sleeping 6 seconds
#
# Working...
# Requesting address: jasper, ga
# Sleeping 6 seconds
#
# Working...
# Requesting address: nantucket, ma
# Sleeping 6 seconds
#
# Working...
# Requesting address: elko, nv
# Sleeping 6 seconds
#
# Working...
# Requesting address: anderson, tn
# Sleeping 6 seconds
#
# Working...
# Requesting address: midland, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: lyon, nv
# Sleeping 6 seconds
#
# Working...
# Requesting address: carson city, nv
# Sleeping 6 seconds
#
# Working...
# Requesting address: hill, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: orange, vt
# Sleeping 6 seconds
#
# Working...
# Requesting address: grand isle, vt
# Sleeping 6 seconds
#
# Working...
# Requesting address: caledonia, vt
# Sleeping 6 seconds
#
# Working...
# Requesting address: lander, nv
# Sleeping 6 seconds
#
# Working...
# Requesting address: blanco, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: hunt, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: jefferson, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: somervell, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: winkler, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: orleans, vt
# Sleeping 6 seconds
#
# Working...
# Requesting address: schleicher, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: stephens, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: fremont, wy
# Sleeping 6 seconds
#
# Working...
# Requesting address: franklin, vt
# Sleeping 6 seconds
#
# Working...
# Requesting address: bastrop, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: ross, oh
# Sleeping 6 seconds
#
# Working...
# Requesting address: lampasas, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: east feliciana, la
# Sleeping 6 seconds
#
# Working...
# Requesting address: nye, nv
# Sleeping 6 seconds
#
# Working...
# Requesting address: gregg, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: mineral, nv
# Sleeping 6 seconds
#
# Working...
# Requesting address: clallam, wa
# Sleeping 6 seconds
#
# Working...
# Requesting address: ector, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: white pine, nv
# Sleeping 6 seconds
#
# Working...
# Requesting address: angelina, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: somerset, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: tioga, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: lawrence, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: newport news, va
# Sleeping 6 seconds
#
# Working...
# Requesting address: st croix, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: rock, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: lincoln, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: marquette, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: fond du lac, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: dodge, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: juneau, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: trempealeau, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: pepin, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: grant, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: burnett, wi
# Sleeping 6 seconds
#
# Working...
# Requesting address: churchill, nv
# Sleeping 6 seconds
#
# Working...
# Requesting address: warren, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: mercer, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: sullivan, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: wichita, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: erath, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: howard, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: kaufman, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: limestone, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: coryell, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: carver, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: stevens, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: mcleod, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: steele, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: aitkin, mn
# Sleeping 6 seconds
#
# Working...
# Requesting address: calhoun, mi
# Sleeping 6 seconds
#
# Working...
# Requesting address: jones, ia
# Sleeping 6 seconds
#
# Working...
# Requesting address: montague, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: essex, vt
# Sleeping 6 seconds
#
# Working...
# Requesting address: clark, wa
# Sleeping 6 seconds
#
# Working...
# Requesting address: benton, ia
# Sleeping 6 seconds
#
# Working...
# Requesting address: doña ana, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: valencia, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: san miguel, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: sierra, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: chaves, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: grant, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: colfax, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: san juan, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: torrance, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: luna, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: roosevelt, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: taos, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: socorro, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: rio arriba, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: catron, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: callahan, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: duval, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: val verde, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: palo pinto, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: hood, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: brazoria, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: bosque, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: comanche, tx
# Sleeping 6 seconds
#
# Working...
# Requesting address: siskiyou, ca
# Sleeping 6 seconds
#
# Working...
# Requesting address: greene, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: elk, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: indiana, pa
# Sleeping 6 seconds
#
# Working...
# Requesting address: apache, az
# Sleeping 6 seconds
#
# Working...
# Requesting address: mckinley, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: cibola, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: eddy, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: union, nm
# Sleeping 6 seconds
#
# Working...
# Requesting address: modoc, ca
# Sleeping 6 seconds

# %%
# create dataframe
insolation_df = pd.DataFrame({'county_state': address_input, 'solar_rad': annual_insol})
insolation_df = insolation_df.drop_duplicates()
insolation_df = insolation_df.reset_index(drop=True)

# %%
# write file
filename = 'insolation_df.csv'
print('Writing to file:', filename)
insolation_df.to_csv(filename, encoding='utf-8', index=False)
print('Finished writing to:', os.getcwd())
# Out:
# Writing to file: insolation_df.csv
# Finished writing to: C:\Users\smouz\OneDrive\Desktop\DataSci\DataSci_Python\SP-Capstone-PY\Capstone
